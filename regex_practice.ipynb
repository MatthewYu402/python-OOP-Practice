# %% [markdown]
# # Python Regex Practice (Easy → Medium → Hard)
#
# This notebook is designed to build your regex skills step-by-step.
#
# ## How to use this notebook
#
# - Read a problem in the **markdown** cell.
# - Implement the function(s) in the **code** cell below it.
# - Each code cell includes **test code** that you should **uncomment** when you think you’re done.
# - Try to solve using the `re` module (and regex) rather than manual parsing, unless the prompt explicitly allows non-regex work.
#
# ## Notes
#
# - Prefer raw strings for patterns: `r"..."`.
# - When validating an entire string, prefer `re.fullmatch()`.
# - When extracting multiple matches, prefer `re.findall()` / `re.finditer()`.
# - Don’t peek at `regex_practice_solutions.md` until you’ve tried.

# %%
# Setup
import re
from typing import List, Tuple, Dict, Optional

# Tip: if you're iterating on patterns, consider compiling:
# pattern = re.compile(r"...")
# pattern.search(text)

# %% [markdown]
# ## Easy Set 1 (Problems 1–3)
#
# ### Problem 1 — Extract integers
# Write `extract_integers(text: str) -> List[int]` that extracts **signed integers** from a string.
#
# - Integers may have an optional leading `+` or `-`.
# - Return them as Python `int`s in the order they appear.
#
# ### Problem 2 — Validate a ZIP code
# Write `is_valid_zip(zip_code: str) -> bool`.
#
# Accept **only**:
# - `12345`
# - `12345-6789`
#
# Reject everything else.
#
# ### Problem 3 — Find capitalized words
# Write `capitalized_words(text: str) -> List[str]` that returns all words that look like:
#
# - First letter uppercase `A-Z`
# - Followed by **one or more** lowercase letters `a-z`
#
# Examples of matches: `Alice`, `Paris`.
# Examples of non-matches: `USA`, `iPhone`, `X`.

# %%
def extract_integers(text: str) -> List[int]:
    """Return all signed integers found in the text."""
    # TODO: implement with regex
    raise NotImplementedError


def is_valid_zip(zip_code: str) -> bool:
    """Return True if zip_code is '12345' or '12345-6789' format."""
    # TODO: implement with regex
    raise NotImplementedError


def capitalized_words(text: str) -> List[str]:
    """Return words like 'Alice'/'Paris' (Capital + lowercase+)."""
    # TODO: implement with regex
    raise NotImplementedError


# --- Tests (uncomment when ready) ---
# assert extract_integers("Order -12 apples, +7 bananas, and 003 pears") == [-12, 7, 3]
# assert extract_integers("no numbers here") == []
#
# assert is_valid_zip("12345") is True
# assert is_valid_zip("12345-6789") is True
# assert is_valid_zip("1234") is False
# assert is_valid_zip("123456") is False
# assert is_valid_zip("12345-678") is False
# assert is_valid_zip("12345-67890") is False
# assert is_valid_zip(" 12345") is False
#
# assert capitalized_words("Alice and Bob went to Paris") == ["Alice", "Bob", "Paris"]
# assert capitalized_words("USA met iPhone in X") == []

# %% [markdown]
# ## Easy Set 2 (Problems 4–6)
#
# ### Problem 4 — Extract email domains
# Write `extract_email_domains(text: str) -> List[str]`.
#
# - Find email-like strings (you can assume they're well-formed for this exercise).
# - Return only the **domain** portion (everything after `@`).
#
# ### Problem 5 — Squash repeated exclamation marks
# Write `squash_exclamations(text: str) -> str` that turns any run of **2 or more** `!` into a single `!`.
#
# ### Problem 6 — Split a loose CSV line
# Write `split_loose_csv(line: str) -> List[str]`.
#
# - Split on commas.
# - Ignore surrounding whitespace around each field.
# - Keep empty fields (e.g., `"a,,b"` has an empty field in the middle).
#
# (You do *not* need to handle quoted CSV fields in this one.)

# %%
def extract_email_domains(text: str) -> List[str]:
    """Return domains from emails found in text."""
    # TODO: implement with regex groups
    raise NotImplementedError


def squash_exclamations(text: str) -> str:
    """Replace '!!', '!!!', ... with a single '!'."""
    # TODO: implement with re.sub
    raise NotImplementedError


def split_loose_csv(line: str) -> List[str]:
    """Split a comma-separated line, trimming whitespace around fields."""
    # TODO: implement with regex (re.split) OR with re.findall
    raise NotImplementedError


# --- Tests (uncomment when ready) ---
# s = "Contact: a.b+test@sub.example.org, root@EXAMPLE.com and not-an-email@"
# assert extract_email_domains(s) == ["sub.example.org", "EXAMPLE.com"]
#
# assert squash_exclamations("Wow!!! Really!!") == "Wow! Really!"
# assert squash_exclamations("No excitement") == "No excitement"
#
# assert split_loose_csv("a, b ,c") == ["a", "b", "c"]
# assert split_loose_csv("a,,b,") == ["a", "", "b", ""]
# assert split_loose_csv("  lone  ") == ["lone"]

# %% [markdown]
# ## Easy Set 3 (Problems 7–9)
#
# ### Problem 7 — Detect a hex color
# Write `contains_hex_color(text: str) -> bool`.
#
# Return True if `text` contains a hex color of the form:
# - `#RGB` (3 hex digits) or
# - `#RRGGBB` (6 hex digits)
#
# Hex digits may be upper or lower case.
#
# ### Problem 8 — Extract YYYY/MM/DD dates
# Write `extract_slash_dates(text: str) -> List[str]`.
#
# - Extract dates like `2026/01/13`.
# - You may assume years are 4 digits.
# - Do basic month/day range validation (month 01–12, day 01–31).
#
# ### Problem 9 — Find long runs of a character
# Write `find_long_runs(text: str) -> List[Tuple[str, int]]`.
#
# Return a list of `(character, run_length)` for each run of the **same character** of length **3 or more**.

# %%
def contains_hex_color(text: str) -> bool:
    """Return True if text contains #RGB or #RRGGBB."""
    # TODO: implement with regex
    raise NotImplementedError


def extract_slash_dates(text: str) -> List[str]:
    """Extract dates in YYYY/MM/DD with basic range validation."""
    # TODO: implement with regex
    raise NotImplementedError


def find_long_runs(text: str) -> List[Tuple[str, int]]:
    """Find runs (length>=3) of the same character."""
    # TODO: implement with regex + backreferences
    raise NotImplementedError


# --- Tests (uncomment when ready) ---
# assert contains_hex_color("paint: #0f8; border: #A1B2c3") is True
# assert contains_hex_color("no color here") is False
# assert contains_hex_color("almost #abcd") is False
#
# t = "Dates: 2026/01/13, 1999/12/31, 2025/00/10, 2025/13/01, 2025/02/32"
# assert extract_slash_dates(t) == ["2026/01/13", "1999/12/31"]
#
# assert find_long_runs("soooo coool!!!") == [("o", 4), ("o", 3), ("!", 3)]
# assert find_long_runs("abc") == []

# %% [markdown]
# ## Easy Set 4 (Problems 10–12)
#
# ### Problem 10 — Normalize phone numbers
# Write `normalize_phone_numbers(text: str) -> List[str]`.
#
# Extract US-style 10-digit phone numbers in any of these forms:
# - `(555) 123-4567`
# - `555-123-4567`
# - `555 123 4567`
#
# Return each number normalized as digits only: `"5551234567"`.
#
# ### Problem 11 — Extract @mentions
# Write `extract_mentions(text: str) -> List[str]`.
#
# A mention is:
# - starts with `@`
# - username starts with a letter
# - then letters/digits/underscore
# - total username length 2–16 characters (including the first letter)
#
# Return usernames **without** the `@`.
#
# ### Problem 12 — Strip simple HTML tags
# Write `strip_simple_html(text: str) -> str`.
#
# Remove HTML tags like `<b>`, `</div>`, `<br/>` from a string.
#
# Note: this is intentionally “simple” HTML stripping for regex practice.

# %%
def normalize_phone_numbers(text: str) -> List[str]:
    """Extract phone numbers and return normalized 10-digit strings."""
    # TODO: implement with regex groups
    raise NotImplementedError


def extract_mentions(text: str) -> List[str]:
    """Extract @mentions and return usernames without '@'."""
    # TODO: implement with regex
    raise NotImplementedError


def strip_simple_html(text: str) -> str:
    """Remove simple HTML tags like <b>...</b>."""
    # TODO: implement with re.sub
    raise NotImplementedError


# --- Tests (uncomment when ready) ---
# t = "Call me at (555) 123-4567 or 555-234-5678 or 555 345 6789."
# assert normalize_phone_numbers(t) == ["5551234567", "5552345678", "5553456789"]
#
# m = "Thanks @alice_1 and @Bob_The_Builder!! but not @9lives or @x"
# assert extract_mentions(m) == ["alice_1", "Bob_The_Builder"]
#
# html = "<div>Hello <b>world</b>!<br/>Bye</div>"
# assert strip_simple_html(html) == "Hello world!Bye"

# %% [markdown]
# ## Medium Set 5 (Problems 13–15)
#
# ### Problem 13 — Parse simple logs
# Write `parse_simple_logs(text: str) -> List[Dict[str, str]]`.
#
# Input is multiple lines. Each valid line looks like:
#
# `LEVEL YYYY-MM-DD message...`
#
# Where:
# - `LEVEL` is one of `INFO`, `WARN`, `ERROR`, `DEBUG`
# - date is `YYYY-MM-DD`
# - message is the rest of the line
#
# Return a list of dicts like:
#
# `{"level": "INFO", "date": "2026-01-13", "message": "Started"}`
#
# Ignore lines that don’t match.
#
# ### Problem 14 — Extract double-quoted strings (with escapes)
# Write `extract_double_quoted(text: str) -> List[str]`.
#
# - Extract content inside `"..."`
# - Support escaped quotes like `\"` inside the quoted string
#
# ### Problem 15 — Validate IPv4
# Write `is_valid_ipv4(addr: str) -> bool`.
#
# Validate dotted IPv4 addresses like `192.168.0.1` where each octet is 0–255.

# %%
def parse_simple_logs(text: str) -> List[Dict[str, str]]:
    """Parse lines like 'INFO 2026-01-13 Started' into dicts."""
    # TODO: implement with regex (consider re.MULTILINE)
    raise NotImplementedError


def extract_double_quoted(text: str) -> List[str]:
    """Extract content inside double quotes, supporting escaped quotes."""
    # TODO: implement with regex
    raise NotImplementedError


def is_valid_ipv4(addr: str) -> bool:
    """Return True if addr is a valid IPv4 address (0-255 in each octet)."""
    # TODO: implement with regex (fullmatch)
    raise NotImplementedError


# --- Tests (uncomment when ready) ---
# logs = """INFO 2026-01-13 Started\nBADLINE\nERROR 2026-01-13 Something failed\nDEBUG 2026-01-14 x=1\n"""
# assert parse_simple_logs(logs) == [
#     {"level": "INFO", "date": "2026-01-13", "message": "Started"},
#     {"level": "ERROR", "date": "2026-01-13", "message": "Something failed"},
#     {"level": "DEBUG", "date": "2026-01-14", "message": "x=1"},
# ]
#
# q = 'He said "hello" then "escaped\\"quote" and "done".'
# assert extract_double_quoted(q) == ["hello", "escaped\\\"quote", "done"]
#
# assert is_valid_ipv4("0.0.0.0") is True
# assert is_valid_ipv4("255.255.255.255") is True
# assert is_valid_ipv4("256.1.1.1") is False
# assert is_valid_ipv4("192.168.1") is False
# assert is_valid_ipv4("192.168.001.1") is True  # leading zeros allowed for this exercise

# %% [markdown]
# ## Medium Set 6 (Problems 16–18)
#
# ### Problem 16 — Parse semicolon key/value pairs
# Write `parse_semicolon_kv(line: str) -> Dict[str, str]`.
#
# Input example:
#
# `"user=alice; id=42; note=\"hello world\""`
#
# Rules:
# - Pairs are separated by `;` with optional whitespace around separators
# - Keys match `[A-Za-z_][A-Za-z0-9_]*`
# - Values are either:
#   - unquoted: any run of characters up to the next `;` (trim outer whitespace)
#   - quoted with double quotes, allowing escaped quotes `\"`
#
# ### Problem 17 — Swap "Last, First" → "First Last"
# Write `swap_name(name: str) -> str`.
#
# - If the input matches `"Last, First"` (single comma), return `"First Last"`.
# - Otherwise, return the input unchanged.
#
# ### Problem 18 — Detect repeated consecutive words
# Write `repeated_words(text: str) -> List[str]`.
#
# Return a list of words that appear **twice in a row**, like:
# - `"the the"`
# - `"Hello hello"` (case-insensitive match)
#
# Return each repeated word as it appears in the first occurrence.

# %%
def parse_semicolon_kv(line: str) -> Dict[str, str]:
    """Parse 'key=value; key2="quoted"' into a dict."""
    # TODO: implement with regex
    raise NotImplementedError


def swap_name(name: str) -> str:
    """Convert 'Last, First' into 'First Last' if it matches."""
    # TODO: implement with regex + re.sub
    raise NotImplementedError


def repeated_words(text: str) -> List[str]:
    """Return words that repeat twice consecutively (case-insensitive)."""
    # TODO: implement with regex + backreferences
    raise NotImplementedError


# --- Tests (uncomment when ready) ---
# line = 'user=alice; id=42; note="hello world"; raw=  spaced  '
# assert parse_semicolon_kv(line) == {"user": "alice", "id": "42", "note": "hello world", "raw": "spaced"}
#
# assert swap_name("Doe, Jane") == "Jane Doe"
# assert swap_name("SingleName") == "SingleName"
# assert swap_name("Last, First, Middle") == "Last, First, Middle"
#
# assert repeated_words("the the quick brown fox") == ["the"]
# assert repeated_words("Hello hello HELLO hello") == ["Hello", "HELLO"]

# %% [markdown]
# ## Medium Set 7 (Problems 19–21)
#
# ### Problem 19 — Extract Markdown links
# Write `extract_markdown_links(md: str) -> List[Tuple[str, str]]`.
#
# Extract links of the form:
#
# `[link text](https://example.com/path)`
#
# Return a list of `(text, url)` tuples.
#
# You can assume:
# - no nested brackets/parentheses inside the link
# - URLs contain no spaces
#
# ### Problem 20 — Find Python function definitions
# Write `python_def_names(code: str) -> List[str]`.
#
# Extract function names from Python code for lines like:
# - `def name(...):`
# - `async def name(...):`
#
# Ignore comments.
#
# ### Problem 21 — Mask card-like digit sequences
# Write `mask_card_numbers(text: str) -> str`.
#
# Find sequences that look like 13–16 digits, possibly separated by spaces or dashes.
#
# Replace all digits except the last 4 with `*`, preserving separators.
#
# Example:
# - `"4111-1111-1111-1111"` → `"****-****-****-1111"`
# - `"4000 0000 0000 1234"` → `"**** **** **** 1234"`

# %%
def extract_markdown_links(md: str) -> List[Tuple[str, str]]:
    """Extract (text, url) from Markdown links like [text](url)."""
    # TODO: implement with regex
    raise NotImplementedError


def python_def_names(code: str) -> List[str]:
    """Extract function names from 'def name(...):' and 'async def name(...):'."""
    # TODO: implement with regex (consider re.MULTILINE)
    raise NotImplementedError


def mask_card_numbers(text: str) -> str:
    """Mask 13-16 digit sequences leaving last 4 digits visible."""
    # TODO: implement with regex + a replacement function
    raise NotImplementedError


# --- Tests (uncomment when ready) ---
# md = "See [Docs](https://example.org/docs) and [API](http://api.example.org/v1)."
# assert extract_markdown_links(md) == [("Docs", "https://example.org/docs"), ("API", "http://api.example.org/v1")]
#
# code = """\n# comment\ndef a(x):\n    return x\n\nasync def fetch(url):\n    pass\n"""
# assert python_def_names(code) == ["a", "fetch"]
#
# s = "Pay with 4111-1111-1111-1111 or 4000 0000 0000 1234; ignore 1234."
# assert mask_card_numbers(s) == "Pay with ****-****-****-1111 or **** **** **** 1234; ignore 1234."

# %% [markdown]
# ## Hard Set 8 (Problems 22–24)
#
# ### Problem 22 — Strong password check
# Write `is_strong_password(pw: str) -> bool`.
#
# Rules:
# - at least 8 characters
# - contains at least one lowercase letter
# - contains at least one uppercase letter
# - contains at least one digit
# - contains at least one special char from: `!@#$%^&*`
# - contains no whitespace
#
# ### Problem 23 — Extract US currency amounts
# Write `extract_us_currency(text: str) -> List[str]`.
#
# Extract amounts like:
# - `$12`
# - `$0.99`
# - `$1,234.56`
# - `$12,345`
#
# Rules:
# - Must start with `$`
# - Commas must be in the correct thousands positions (e.g., `$12,34` is invalid)
# - Decimal part, if present, is exactly two digits
#
# ### Problem 24 — Replace a standalone word
# Write `replace_standalone_word(text: str, word: str, repl: str) -> str`.
#
# Replace occurrences of `word` only when it appears as a **whole word** (not inside another word).
#
# Hint: use word boundaries and `re.escape`.

# %%
def is_strong_password(pw: str) -> bool:
    """Check password strength using regex-based rules."""
    # TODO: implement with regex (lookaheads can help)
    raise NotImplementedError


def extract_us_currency(text: str) -> List[str]:
    """Extract currency amounts like $1,234.56 with correct comma placement."""
    # TODO: implement with regex
    raise NotImplementedError


def replace_standalone_word(text: str, word: str, repl: str) -> str:
    """Replace word only when it appears as a whole word."""
    # TODO: implement with regex + re.escape
    raise NotImplementedError


# --- Tests (uncomment when ready) ---
# assert is_strong_password("Aa1!aaaa") is True
# assert is_strong_password("short1!") is False
# assert is_strong_password("NOLOWER1!") is False
# assert is_strong_password("noupper1!") is False
# assert is_strong_password("NoDigit!!") is False
# assert is_strong_password("NoSpecial1") is False
# assert is_strong_password("Has Space1!") is False
#
# t = "Prices: $12, $0.99, $1,234.56, $12,34, $1234.56, $12,345"
# assert extract_us_currency(t) == ["$12", "$0.99", "$1,234.56", "$12,345"]
#
# assert replace_standalone_word("cat scatter concatenate", "cat", "dog") == "dog scatter concatenate"
# assert replace_standalone_word("(cat), cat!", "cat", "dog") == "(dog), dog!"

# %% [markdown]
# ## Hard Set 9 (Problems 25–27)
#
# ### Problem 25 — Parse an ISO-8601 datetime
# Write `parse_iso8601(dt: str) -> Optional[Dict[str, str]]`.
#
# Accept strings like:
# - `2026-01-13T14:05Z`
# - `2026-01-13 14:05:09+02:30`
# - `1999-12-31T23:59:59-05:00`
#
# Rules:
# - Date is `YYYY-MM-DD`
# - Separator is `T` or a space
# - Time is `HH:MM` with optional `:SS`
# - Timezone is required: `Z` or `+HH:MM` or `-HH:MM`
#
# Return a dict with keys:
# `year, month, day, hour, minute, second, tz`
#
# If seconds are missing, set `second` to `"00"`.
# Return `None` if the string doesn’t match.
#
# ### Problem 26 — Words that start and end with the same letter
# Write `words_same_ends(text: str) -> List[str]`.
#
# Return words (letters only) of length >= 2 where the **first and last** letter are the same (case-insensitive).
#
# Examples: `level`, `AlA`, `noon`.
#
# ### Problem 27 — Overlapping 3-character palindromes
# Write `overlapping_pal3(text: str) -> List[str]`.
#
# Return all overlapping 3-character palindromes like `aba`, `xyx`.
#
# Example: `"ababa"` contains `"aba"`, `"bab"`, `"aba"`.
#
# Hint: lookaheads enable overlapping matches.

# %%
def parse_iso8601(dt: str) -> Optional[Dict[str, str]]:
    """Parse ISO-8601 datetime into components, or return None."""
    # TODO: implement with regex (named groups recommended)
    raise NotImplementedError


def words_same_ends(text: str) -> List[str]:
    """Return letter-only words where first==last (case-insensitive), length>=2."""
    # TODO: implement with regex + backreferences
    raise NotImplementedError


def overlapping_pal3(text: str) -> List[str]:
    """Return overlapping 3-character palindromes."""
    # TODO: implement with regex lookahead
    raise NotImplementedError


# --- Tests (uncomment when ready) ---
# assert parse_iso8601("2026-01-13T14:05Z") == {
#     "year": "2026", "month": "01", "day": "13",
#     "hour": "14", "minute": "05", "second": "00", "tz": "Z"
# }
# assert parse_iso8601("2026-01-13 14:05:09+02:30") == {
#     "year": "2026", "month": "01", "day": "13",
#     "hour": "14", "minute": "05", "second": "09", "tz": "+02:30"
# }
# assert parse_iso8601("bad") is None
#
# assert words_same_ends("Level deed noon test AlA X") == ["Level", "deed", "noon", "AlA"]
#
# assert overlapping_pal3("ababa") == ["aba", "bab", "aba"]
# assert overlapping_pal3("abcdef") == []

# %% [markdown]
# ## Hard Set 10 (Problems 28–30)
#
# ### Problem 28 — Parse `Name <email>`
# Write `parse_name_email(s: str) -> Optional[Tuple[str, str]]`.
#
# Accept forms:
# - `Grace Hopper <grace@navy.mil>`
# - `"Ada Lovelace" <ada@calc.org>`
# - `<solo@x.io>` (name is empty)
#
# Return `(name, email)` where `name` is unquoted if quoted.
# Return `None` if it doesn’t match.
#
# ### Problem 29 — Extract http/https URLs
# Write `extract_urls(text: str) -> List[str]`.
#
# Extract URLs that start with `http://` or `https://` and continue until whitespace.
#
# Then strip trailing punctuation characters from the end of the URL if present: `. , ) ] ! ? : ;`
#
# (You can do this with regex alone or with a small post-processing step.)
#
# ### Problem 30 — Validate Roman numerals (1–3999)
# Write `is_valid_roman(s: str) -> bool`.
#
# Validate uppercase Roman numerals representing values 1 to 3999.
#
# Examples: `I`, `IV`, `XII`, `MCMXCIX`.
# Non-examples: `IIII`, `VV`, `IC`, empty string.

# %%
def parse_name_email(s: str) -> Optional[Tuple[str, str]]:
    """Parse 'Name <email>' or '<email>' into (name, email), else None."""
    # TODO: implement with regex
    raise NotImplementedError


def extract_urls(text: str) -> List[str]:
    """Extract http/https URLs and remove trailing punctuation."""
    # TODO: implement with regex
    raise NotImplementedError


def is_valid_roman(s: str) -> bool:
    """Validate Roman numerals from I to MMMCMXCIX (1-3999)."""
    # TODO: implement with regex (fullmatch)
    raise NotImplementedError


# --- Tests (uncomment when ready) ---
# assert parse_name_email('Grace Hopper <grace@navy.mil>') == ("Grace Hopper", "grace@navy.mil")
# assert parse_name_email('"Ada Lovelace" <ada@calc.org>') == ("Ada Lovelace", "ada@calc.org")
# assert parse_name_email('<solo@x.io>') == ("", "solo@x.io")
# assert parse_name_email('bad <not-an-email>') is None
#
# t = "See https://example.org/docs, and (http://api.example.org/v1)!"
# assert extract_urls(t) == ["https://example.org/docs", "http://api.example.org/v1"]
#
# assert is_valid_roman("I") is True
# assert is_valid_roman("IV") is True
# assert is_valid_roman("MCMXCIX") is True
# assert is_valid_roman("MMMCMXCIX") is True
# assert is_valid_roman("") is False
# assert is_valid_roman("IIII") is False
# assert is_valid_roman("IC") is False
